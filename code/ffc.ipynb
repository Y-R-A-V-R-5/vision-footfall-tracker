# %%
# ============================================================
# 🧠 Human Head Detection — YOLOv8 Training Configuration
# ============================================================
# This script fine-tunes a pretrained YOLOv8s model to detect
# human heads in varied environments (overhead, corridor, etc.).
# All external loggers (MLflow, W&B, Neptune, etc.) are disabled
# to ensure smooth offline training with local run tracking only.
# ============================================================

# %%
# ------------------------------------------------------------
# 1️⃣ Imports & Logger Settings
# ------------------------------------------------------------
from ultralytics import YOLO, settings

# Disable all external experiment trackers
settings.update({
    "mlflow": False,
    "wandb": False,
    "clearml": False,
    "comet": False,
    "neptune": False,
    "raytune": False,
    "tensorboard": False,
    "hub": False,
    "dvc": False
})

# %%
# ------------------------------------------------------------
# 2️⃣ Model: YOLOv8m — Medium Variant
# ------------------------------------------------------------
# This model balances accuracy and speed for real-time applications.
model1 = YOLO("../sota/yolov8m.pt")

model1.info()  # view model summary
# Out:
# YOLOv8m summary: 169 layers, 25,902,640 parameters, 0 gradients, 79.3 GFLOPs
# (169, 25902640, 0, 79.3204224)

# %%
results = model1.train(
    data="../datasets/human-head-detection-openvm/data.yaml",  # dataset config
    epochs=100,
    imgsz=320,
    batch=16,
    workers=2,
    name="medium",
    project="../../ffc/runs/train",   # ✅ store results here
    exist_ok=True,
    pretrained=True,
    cache=True,

    # Augmentations
    degrees=5.0,
    translate=0.1,
    scale=0.5,
    shear=2.0,
    flipud=0.1,
    fliplr=0.5,
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,

    # Optimization / Regularization
    patience=15,
    optimizer="Adam",
    lr0=0.001,
    lrf=0.01,
    momentum=0.937,
    weight_decay=0.0005,
    warmup_epochs=10,
    label_smoothing=0.1,
    cos_lr=True,

    # Checkpoints
    save_period=5,

    # Disable all external tracking
    tracker=None
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.225 available  Update with 'pip install -U ultralytics'
# WARNING 'label_smoothing' is deprecated and will be removed in the future.
# Ultralytics 8.3.220  Python-3.10.18 torch-2.8.0+cpu CPU (12th Gen Intel Core i5-12500)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=True, cutmix=0.0, data=../datasets/human-head-detection-openvm/data.yaml, degrees=5.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.1, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=320, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=../sota/yolov8m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=medium, nbs=64, nms=False, opset=None, optimize=False, optimizer=Adam, overlap_mask=True, patience=15, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=../../ffc/runs/train, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\Kapil IT Skill HUB\Desktop\ffc\runs\train\medium, save_frames=False, save_json=False, save_period=5, save_txt=False, scale=0.5, seed=0, shear=2.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=None, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=10, warmup_momentum=0.8, weight_decay=0.0005, workers=2, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776275  ultralytics.nn.modules.head.Detect           [1, [192, 384, 576]]
# Model summary: 169 layers, 25,856,899 parameters, 25,856,883 gradients, 79.1 GFLOPs
#
# Transferred 469/475 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Fast image access  (ping: 0.40.2 ms, read: 21.35.3 MB/s, size: 42.1 KB)
# train: Scanning C:\Users\Kapil IT Skill HUB\Desktop\ffc\datasets\human-head-detection-openvm\train\labels.cache... 1426 images, 86 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 1426/1426  0.0s
# WARNING cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (0.4GB RAM): 100% ━━━━━━━━━━━━ 1426/1426 1.0Kit/s 1.4s0.1ss
# albumentations: ImageCompression.__init__() got an unexpected keyword argument 'quality_range'
# val: Fast image access  (ping: 0.20.1 ms, read: 33.67.8 MB/s, size: 38.0 KB)
# val: Scanning C:\Users\Kapil IT Skill HUB\Desktop\ffc\datasets\human-head-detection-openvm\valid\labels.cache... 160 images, 9 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 160/160  0.0s
# WARNING cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (0.0GB RAM): 100% ━━━━━━━━━━━━ 160/160 1.1Kit/s 0.1s<0.1s
# Plotting labels to C:\Users\Kapil IT Skill HUB\Desktop\ffc\runs\train\medium\labels.jpg...
# optimizer: Adam(lr=0.001, momentum=0.937) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Image sizes 320 train, 320 val
# Using 0 dataloader workers
# Logging results to C:\Users\Kapil IT Skill HUB\Desktop\ffc\runs\train\medium
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100         0G      1.551      1.325       1.49          1        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:521.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 15.1s4.0s
#                    all        160        216      0.801      0.673      0.757      0.398
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100         0G      1.494      1.166      1.451          4        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:411.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.9s3.9s
#                    all        160        216       0.91      0.773      0.871      0.515
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100         0G      1.469      1.066      1.443          3        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:371.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.9s3.9s
#                    all        160        216      0.893      0.634      0.802      0.451
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100         0G      1.466      1.109      1.443          1        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:381.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.8s3.9s
#                    all        160        216      0.846      0.684      0.763      0.447
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100         0G       1.46      1.136       1.44          2        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:371.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.9s3.9s
#                    all        160        216      0.791      0.764      0.832       0.44
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100         0G      1.453      1.079      1.449          6        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:351.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.9s3.9s
#                    all        160        216      0.847      0.838      0.899      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100         0G      1.414      1.043      1.423          7        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:151.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.6s4.4ss
#                    all        160        216       0.72      0.648      0.685      0.374
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100         0G      1.438      1.055       1.43          1        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:141.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.7s4.4ss
#                    all        160        216      0.831      0.815      0.867      0.509
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100         0G      1.427      1.058      1.436          1        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:131.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.7s4.4ss
#                    all        160        216      0.807      0.773      0.843      0.488
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100         0G       1.42      1.035       1.42          4        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:111.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.7s4.4ss
#                    all        160        216      0.878      0.819      0.892      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100         0G      1.428      1.026      1.415          6        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:131.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.8s4.4ss
#                    all        160        216      0.811      0.815      0.874      0.481
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100         0G      1.424      1.024      1.415          7        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:131.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.6s4.4ss
#                    all        160        216      0.864      0.825      0.921      0.544
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100         0G      1.394     0.9806      1.403          3        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:141.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.9s4.5ss
#                    all        160        216      0.869      0.797      0.885       0.52
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100         0G      1.401     0.9864       1.41          2        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:141.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.8s4.4ss
#                    all        160        216      0.855      0.847      0.905       0.55
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100         0G      1.386     0.9836      1.398          4        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:131.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.7s4.4ss
#                    all        160        216       0.92      0.861      0.933      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100         0G       1.36     0.9241      1.377          2        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:351.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 15.0s3.9s
#                    all        160        216      0.912      0.866      0.926      0.547
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100         0G      1.334     0.9245      1.375          1        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:351.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 15.0s4.0s
#                    all        160        216      0.833      0.875      0.905      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100         0G      1.349     0.9359      1.394          3        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:341.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 15.1s4.0s
#                    all        160        216      0.929      0.853      0.932      0.569
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100         0G      1.341     0.9367      1.371          1        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:321.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 15.0s3.9s
#                    all        160        216      0.921      0.919      0.964      0.567
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100         0G      1.329     0.8708      1.359          4        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:341.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.9s3.9s
#                    all        160        216      0.907      0.843      0.924      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100         0G      1.325      0.868      1.354          5        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:341.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.9s3.9s
#                    all        160        216      0.857      0.804      0.882      0.537
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100         0G      1.313     0.8445      1.356          6        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:371.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.9s3.9s
#                    all        160        216      0.889      0.849      0.912      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100         0G      1.314     0.8705      1.357          5        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:141.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.9s4.4ss
#                    all        160        216      0.912      0.867      0.943      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100         0G      1.325     0.8465      1.359          2        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:141.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.8s4.4ss
#                    all        160        216       0.92       0.88      0.946       0.58
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100         0G      1.315     0.8544      1.352          3        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:151.8ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.7s4.4ss
#                    all        160        216      0.935      0.872      0.943      0.568
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100         0G       1.26       0.82      1.336          3        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:141.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.8s4.4ss
#                    all        160        216      0.872      0.889      0.934      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100         0G      1.307     0.8292       1.36          8        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:131.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.8s4.4ss
#                    all        160        216      0.909      0.861       0.94      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100         0G      1.256     0.8162      1.333          2        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:131.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.8s4.4ss
#                    all        160        216      0.913      0.829      0.918      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100         0G        1.3     0.8012      1.352          5        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:131.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.7s4.4ss
#                    all        160        216       0.94      0.843       0.94      0.576
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100         0G      1.275     0.8031       1.33          6        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:331.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.9s3.9s
#                    all        160        216      0.927      0.884      0.964      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100         0G      1.267     0.7973      1.338          5        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:361.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 15.0s3.9s
#                    all        160        216      0.861      0.903      0.943      0.596
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100         0G      1.273     0.7971      1.338          5        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:331.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.9s3.9s
#                    all        160        216      0.916      0.858      0.932      0.588
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100         0G      1.246     0.7904      1.324          3        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:341.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.9s4.0s
#                    all        160        216      0.873      0.891      0.934      0.593
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100         0G      1.225     0.7499      1.308          4        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:321.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.9s3.9s
#                    all        160        216      0.931       0.87       0.95      0.586
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100         0G      1.227     0.7565      1.313          6        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:111.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.7s4.4ss
#                    all        160        216      0.953      0.848      0.944      0.561
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100         0G       1.23     0.7507      1.311          3        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:111.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.7s4.4ss
#                    all        160        216      0.938      0.907      0.954      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100         0G      1.223      0.741      1.301          5        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:331.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.9s3.9s
#                    all        160        216      0.907      0.898      0.956      0.599
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100         0G      1.209     0.7259       1.29          5        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:321.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 14.9s3.9s
#                    all        160        216      0.927      0.881      0.956      0.592
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100         0G      1.197     0.7314      1.279          2        320: 100% ━━━━━━━━━━━━ 90/90 0.3it/s 5:331.5ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 15.0s3.9s
#                    all        160        216       0.88      0.914      0.942      0.565
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100         0G      1.197     0.7279      1.287          5        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:141.3ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.7s4.4ss
#                    all        160        216      0.924      0.912      0.962      0.611
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100         0G      1.166       0.71      1.264          5        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:151.7ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.8s4.4ss
#                    all        160        216      0.914      0.898      0.954      0.602
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100         0G      1.172     0.6901      1.288          4        320: 100% ━━━━━━━━━━━━ 90/90 0.2it/s 6:141.4ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.3it/s 16.9s4.4ss
#                    all        160        216      0.938      0.884      0.956      0.604
# EarlyStopping: Training stopped early as no improvement observed in last 15 epochs. Best results observed at epoch 27, best model saved as best.pt.
# To update EarlyStopping(patience=15) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 42 epochs completed in 4.339 hours.
# Optimizer stripped from C:\Users\Kapil IT Skill HUB\Desktop\ffc\runs\train\medium\weights\last.pt, 52.0MB
# Optimizer stripped from C:\Users\Kapil IT Skill HUB\Desktop\ffc\runs\train\medium\weights\best.pt, 52.0MB
#
# Validating C:\Users\Kapil IT Skill HUB\Desktop\ffc\runs\train\medium\weights\best.pt...
# Ultralytics 8.3.220  Python-3.10.18 torch-2.8.0+cpu CPU (12th Gen Intel Core i5-12500)
# Model summary (fused): 92 layers, 25,840,339 parameters, 0 gradients, 78.7 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 5/5 0.4it/s 13.5s3.6s
#                    all        160        216      0.909      0.861       0.94      0.611
# Speed: 0.4ms preprocess, 81.3ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to C:\Users\Kapil IT Skill HUB\Desktop\ffc\runs\train\medium

# %%
# ------------------------------------------------------------
# 4️⃣ Training Completion Summary
# ------------------------------------------------------------
print("\n✅ Training completed successfully!")
print(f"📂 Results directory: {results.save_dir}")
print("📈 Metrics, weights, and visualizations saved locally.")
# The trained model can now be evaluated or deployed for head detection tasks.
# Out:
# ✅ Training completed successfully!
# 📂 Results directory: C:\Users\Kapil IT Skill HUB\Desktop\ffc\runs\train\medium
# 📈 Metrics, weights, and visualizations saved locally.
